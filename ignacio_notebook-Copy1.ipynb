# %%
import pandas as pd
import numpy as np


pd.set_option('display.max_columns', 10000)

# %%
df=pd.read_csv('judge-1377884607_tweet_product_company.csv',encoding = 'unicode_escape')

# %%
df
# Out:
#                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1     @jessedee Know about @fludapp ? Awesome iPad/i...
# 2     @swonderlin Can not wait for #iPad 2 also. The...
# 3     @sxsw I hope this year's festival isn't as cra...
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa M...
# ...                                                 ...
# 9088                      Ipad everywhere. #SXSW {link}
# 9089  Wave, buzz... RT @mention We interrupt your re...
# 9090  Google's Zeiger, a physician never reported po...
# 9091  Some Verizon iPhone customers complained their...
# 9092  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
#
#      emotion_in_tweet_is_directed_at  \
# 0                             iPhone
# 1                 iPad or iPhone App
# 2                               iPad
# 3                 iPad or iPhone App
# 4                             Google
# ...                              ...
# 9088                            iPad
# 9089                             NaN
# 9090                             NaN
# 9091                             NaN
# 9092                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 0                                      Negative emotion
# 1                                      Positive emotion
# 2                                      Positive emotion
# 3                                      Negative emotion
# 4                                      Positive emotion
# ...                                                 ...
# 9088                                   Positive emotion
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product
#
# [9093 rows x 3 columns]

# %%
df.columns=['tweet','company','emotion']

# %%
df=df.drop([6]).reset_index(drop=True)

# %%
df['emotion'] = df['emotion'].apply(lambda x: "No emotion toward brand or product" if x == "I can't tell" else x)

# %%
df.emotion.value_counts()
# Out:
# No emotion toward brand or product    5544
# Positive emotion                      2978
# Negative emotion                       570
# Name: emotion, dtype: int64

# %%
df[df.company.isna()]
# Out:
#                                                   tweet company  \
# 5     @teachntech00 New iPad Apps For #SpeechTherapy...     NaN
# 15    Holler Gram for iPad on the iTunes App Store -...     NaN
# 31    Attn: All  #SXSW frineds, @mention Register fo...     NaN
# 32        Anyone at  #sxsw want to sell their old iPad?     NaN
# 33    Anyone at  #SXSW who bought the new iPad want ...     NaN
# ...                                                 ...     ...
# 9086  @mention Yup, but I don't have a third app yet...     NaN
# 9088  Wave, buzz... RT @mention We interrupt your re...     NaN
# 9089  Google's Zeiger, a physician never reported po...     NaN
# 9090  Some Verizon iPhone customers complained their...     NaN
# 9091  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...     NaN
#
#                                  emotion
# 5     No emotion toward brand or product
# 15    No emotion toward brand or product
# 31    No emotion toward brand or product
# 32    No emotion toward brand or product
# 33    No emotion toward brand or product
# ...                                  ...
# 9086  No emotion toward brand or product
# 9088  No emotion toward brand or product
# 9089  No emotion toward brand or product
# 9090  No emotion toward brand or product
# 9091  No emotion toward brand or product
#
# [5801 rows x 3 columns]

# %%
df[df.emotion=='No emotion toward brand or product'].company.value_counts()
# Out:
# iPad                               28
# Apple                              23
# Google                             16
# Other Google product or service    10
# iPhone                             10
# iPad or iPhone App                 10
# Android App                         1
# Android                             1
# Other Apple product or service      1
# Name: company, dtype: int64

# %%
df[df.emotion=='No emotion toward brand or product'].company.isna().sum()
# Out:
# 5444

# %%
punctuation=[",",".","#","!","@","$","?","$","%","&","-","_", ";","<",">",'/',"\''","{","}"]
apple=['iPhone',"iPad&quot;","iphone ",'i Pad','i Pad',"Apple.","iPad?","#iPad","#iPhone",'iPad','Mac',"iphone,",'iPod','ipod','ipad','mac','Apple','apple','Apple\'s','apple\'s',"#Apple",'#apple','I-Pad']
google=['Google','google','android','Android','Google.','android,',"#android",'Google\'s','google\'s','googles' ,'#google','#Google']

# %%
for index in df.index:
    tweet = "".join( i if i not in punctuation else " " for i in df.tweet[index])
    condition=0
    if bool(set(tweet.split())&set(apple)) == True:
        df.company[index]=(list(set(tweet.split())&set(apple))[0].title().strip('\'s')).strip("\'S")
        condition=1
    else:
        condition=0
         
    if (bool(set(tweet.split())&set(google)) == True) and condition ==0:
        df.company[index]=(list(set(tweet.split())&set(google))[0].title().strip('\'s')).strip("\'S")
    elif(bool(set(tweet.split())&set(google)) == True) and condition ==1: 
        df.company[index]+= " & "+(list(set(tweet.split())&set(google))[0].title().strip('\'s')).strip("\'S")

# %%
df['company'] = df['company'].apply(lambda x: "ipad" if x == "Ipad" else x)
df['company'] = df['company'].apply(lambda x: "iphone" if x == "Iphone" else x)

# %%
df.company.value_counts()
# Out:
# Google                             2382
# iPad                               1981
# Apple                              1961
# iphone                             1051
# Android                             376
# Iphone & Android                    119
# iPad or iPhone App                   57
# iPhone                               47
# Ipad & Android                       31
# Apple & Google                       23
# Ipod                                 15
# Mac                                  14
# Other Apple product or service       12
# Apple & Android                       7
# Ipad & Google                         5
# Iphone & Google                       4
# Other Google product or service       4
# Ipod & Android                        1
# Mac & Android                         1
# Name: company, dtype: int64

# %%
df[['company','emotion','tweet']].groupby(['company','emotion']).count()
# Out:
#                                                                     tweet
# company                         emotion
# Android                         Negative emotion                       17
#                                 No emotion toward brand or product    210
#                                 Positive emotion                      149
# Apple                           Negative emotion                      106
#                                 No emotion toward brand or product   1082
#                                 Positive emotion                      773
# Apple & Android                 No emotion toward brand or product      4
#                                 Positive emotion                        3
# Apple & Google                  Negative emotion                        1
#                                 No emotion toward brand or product     14
#                                 Positive emotion                        8
# Google                          Negative emotion                      133
#                                 No emotion toward brand or product   1585
#                                 Positive emotion                      664
# Ipad                            Negative emotion                      156
#                                 No emotion toward brand or product    970
#                                 Positive emotion                      796
# Ipad & Android                  No emotion toward brand or product     27
#                                 Positive emotion                        4
# Ipad & Google                   No emotion toward brand or product      3
#                                 Positive emotion                        2
# Iphone                          Negative emotion                      104
#                                 No emotion toward brand or product    576
#                                 Positive emotion                      371
# Iphone & Android                Negative emotion                        4
#                                 No emotion toward brand or product     82
#                                 Positive emotion                       33
# Iphone & Google                 No emotion toward brand or product      1
#                                 Positive emotion                        3
# Ipod                            No emotion toward brand or product      9
#                                 Positive emotion                        6
# Ipod & Android                  Negative emotion                        1
# Mac                             Negative emotion                        2
#                                 No emotion toward brand or product      8
#                                 Positive emotion                        4
# Mac & Android                   Positive emotion                        1
# Other Apple product or service  Positive emotion                       12
# Other Google product or service Negative emotion                        1
#                                 Positive emotion                        3
# iPad                            Negative emotion                        9
#                                 No emotion toward brand or product      2
#                                 Positive emotion                       48
# iPad or iPhone App              Negative emotion                        6
#                                 No emotion toward brand or product      1
#                                 Positive emotion                       50
# iPhone                          Negative emotion                       24
#                                 No emotion toward brand or product      4
#                                 Positive emotion                       19

# %%
df[df.company.isna()]
# Out:
#                                                   tweet company  \
# 50    ÛÏ@mention {link} &lt;-- HELP ME FORWARD THIS...     NaN
# 51    ÷¼ WHAT? ÷_ {link} ã_ #edchat #musedchat #s...     NaN
# 52    .@mention @mention on the location-based 'fast...     NaN
# 64    Agree. RT @mention Wait. FIONA APPLE is in tow...     NaN
# 65    At #sxsw? @mention / @mention wanna buy you a ...     NaN
# ...                                                 ...     ...
# 9025  True story! RT @mention I just rated Amy's Ice...     NaN
# 9042  Hey is anyone doing #sxsw signing up for the g...     NaN
# 9068  @mention You're not sure how many you ate? Tha...     NaN
# 9072  At #SXSW your iphone charger is your best friend.     NaN
# 9073  At &quot;Your Mom Has an iPad: Designing for B...     NaN
#
#                                  emotion
# 50    No emotion toward brand or product
# 51    No emotion toward brand or product
# 52    No emotion toward brand or product
# 64    No emotion toward brand or product
# 65    No emotion toward brand or product
# ...                                  ...
# 9025  No emotion toward brand or product
# 9042                    Negative emotion
# 9068  No emotion toward brand or product
# 9072  No emotion toward brand or product
# 9073  No emotion toward brand or product
#
# [1001 rows x 3 columns]
